# %% [markdown]
# # **Text Summarization Script**
#
# **Note**: To run on GPU, go to **Edit** -> **Notebook settings** and set **Hardware accelerator** to **GPU**.

# %%
# mount google drive and paste authorization code
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# change to working directory
# %cd '/content/gdrive/MyDrive/CSE512 Project/code'
# Out:
# /content/gdrive/.shortcut-targets-by-id/1sIjQ-NZ6kHehDdbCSP79olCNjhK8VZMr/CSE512 Project/code

# %%
# !pip install -r requirements.txt

# %%
# !pip install transformers

# %%
# !python run_summarization.py --model_name_or_path t5-small \
                            --dataset_name cnn_dailymail \
                            --dataset_config "3.0.0" \
                            --source_prefix "summarize:" \
                            --num_train 10000 \
                            --num_train_epochs 1 \
                            --per_device_train_batch_size 4 \
                            --per_device_eval_batch_size 4 \
                            --output_dir output
# Out:
# 11/28/2021 20:36:47 - INFO - __main__ - Distributed environment: NO
# Num processes: 1
# Process index: 0
# Local process index: 0
# Device: cuda
# Use FP16 precision: False
#
# Downloading: 9.35kB [00:00, 8.20MB/s]
# Downloading: 9.50kB [00:00, 9.57MB/s]
# ...
#   0% 0/5 [00:00<?, ?it/s]
# Downloading:   0% 0.00/159M [00:00<?, ?B/s]
# Downloading:   2% 3.12M/159M [00:00<00:04, 31.2MB/s]
# Downloading:   4% 6.79M/159M [00:00<00:04, 34.4MB/s]
# Downloading:   7% 10.4M/159M [00:00<00:04, 35.0MB/s]
# Downloading:   9% 14.1M/159M [00:00<00:03, 36.1MB/s]
# Downloading:  11% 17.8M/159M [00:00<00:04, 35.0MB/s]
# Downloading:  13% 21.3M/159M [00:00<00:04, 34.3MB/s]
# Downloading:  16% 24.9M/159M [00:00<00:03, 35.0MB/s]
# Downloading:  18% 28.4M/159M [00:00<00:03, 34.7MB/s]
# Downloading:  20% 32.0M/159M [00:00<00:03, 35.0MB/s]
# Downloading:  22% 35.7M/159M [00:01<00:03, 35.5MB/s]
# Downloading:  25% 39.2M/159M [00:01<00:03, 35.1MB/s]
# Downloading:  27% 42.8M/159M [00:01<00:03, 35.3MB/s]
# ...
